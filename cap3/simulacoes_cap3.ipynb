# %% [markdown]
# # Processamento Digital de Imagens - Cap 3
#
# <br><br>Professor: PAULO CESAR CORTEZ<br><br>
# Aluno: Antônio Ricardo C. Alcântara Junior<br><br>
# Esse notebook tem a simulação de algumas imagens do capítulo 3 do livro Processamento Digital de Imagens gonzalez 3 ed, Rafael C. Gonzalez <br><br>
# Exemplos:
# * <a href='#imagem1'> 3.9 </a>
# * <a href='#imagem2'>3.10; </a>
# * <a href='#imagem3'>3.12; </a>
# * <a href='#imagem4'>3.14; </a>
# * <a href='#imagem5'>3.20; </a>
# * <a href='#imagem6'>3.24; </a>
# * <a href='#imagem7'>3.25; </a>
# * <a href='#imagem8'>3.26; </a>
# * <a href='#imagem9'>3.27; </a>
# * <a href='#imagem10'>3.33; </a>
# * <a href='#imagem11'>3.34; </a>
# * <a href='#imagem12'>3.35; </a>
# * <a href='#imagem13'>3.38; </a>
# * <a href='#imagem14'>3.40; </a>
# * <a href='#imagem15'>3.42; </a>
# * <a href='#imagem16'>3.43; </a>

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.pyplot import imshow
import matplotlib.image as mpimg
from skimage.io import imread

# %%
imagens = ['imagem3.9.tif', 'imagem3.10.tif', 'imagem3.12.tif', 'imagem3.14.tif', 'imagem3.201.tif', 'imagem3.202.tif', 'imagem3.203.tif','imagem3.204.tif','imagem3.24.tif', 'imagem3.26.tif', 'imagem3.27.tif', 'imagem3.33.tif', 'imagem3.34.tif', 'imagem3.35.tif', 'imagem3.38.tif', 'imagem3.40.tif', 'imagem3.42.tif', 'imagem3.43.tif', 'imagem3.54.tif']

# %% [markdown]
# # <p id= 'imagem1'>Imagem 3.9</p>

# %%
#Imagem 1 - Função Gama - 3.9
def adjust_gamma(image, gamma=1.0):
    table = np.array([((i / 255.0) ** gamma) * 255
        for i in np.arange(0, 256)]).astype("uint8")
    return cv.LUT(image, table)

# %%
gama = [1, 3, 4, 5]
img = imread("entradas/"+imagens[0])
imagem1 = adjust_gamma(img,gama[0])
imgplot = plt.imshow(imagem1, cmap='gray', vmin=0, vmax=255)

# %%
gama = [1, 3, 4, 5]
imagem1 = adjust_gamma(img,gama[1])
imgplot = plt.imshow(imagem1, cmap='gray', vmin=0, vmax=255)

# %%
gama = [1, 3, 4, 5]
imagem1 = adjust_gamma(img,gama[2])
imgplot = plt.imshow(imagem1, cmap='gray', vmin=0, vmax=255)

# %%
gama = [1, 3, 4, 5]
imagem1 = adjust_gamma(img,gama[3])
imgplot = plt.imshow(imagem1, cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# # <p id= 'imagem2'>Imagem 3.10</p>

# %%
def alargamento_de_contraste(image):
  min = np.amin(image)
  max = np.amax(image)
  return ((image - min)/(max - min))*255

# %%
def limiarizacao(image):
  min = np.mean(image)
  return (image - min)*255

# %%
image = imread("entradas/"+imagens[1])
imshow(image, cmap='gray', vmin=0, vmax=255);

# %%
image_applied = alargamento_de_contraste(image)
imshow(image_applied, cmap='gray', vmin=0, vmax=255);

# %%
image_applied = limiarizacao(image)
imshow(image_applied, cmap='gray', vmin=0, vmax=255);

# %% [markdown]
# # <p id= 'imagem3'>Imagem 3.12</p>

# %%
def fatiamento(image, A, B):
    image_applied = image.copy()
    image_applied[image < A] = 0
    image_applied[np.logical_and(image > A, image < B)] = 255
    return image_applied

# %%
def fatiamento2(image, A, B):
    image_applied = image.copy()
    image_applied[np.logical_or(image < A, image > B)] = 30
    image_applied[image < 80] = 2*image_applied[image < 80]
    return image_applied

# %%
image = imread('entradas/' + imagens[2])
imshow(image, cmap='gray', vmin=0, vmax=255);

# %%
image_applied = fatiamento(image, 140, 255)
imshow(image_applied, cmap='gray', vmin=0, vmax=255);

# %%
image_applied = fatiamento2(image, 146, 255)
imshow(image_applied, cmap='gray', vmin=0, vmax=255);

# %% [markdown]
# # <p id= 'imagem4'>Imagem 3.14</p>

# %%
def fatiamento(image, plane):
    a = image
    p = np.array(
                 [[int(np.binary_repr(a[i][j], 8)[8 - plane]) * 255
                   for j in range(0, a.shape[1])]
                  for i in range(0, a.shape[0])])
    return p

# %%
a = image.copy()

int(np.binary_repr(a[1][1], 8)[8 - 3])*255
# Out:
# 0

# %%
image = imread('entradas/' + imagens[3])
imshow(image, cmap='gray', vmin=0, vmax=255);

# %%
image_applied = fatiamento(image, 1)
imshow(image_applied, cmap='gray', vmin=0, vmax=255);

# %%
image_applied = fatiamento(image, 2)
imshow(image_applied, cmap='gray', vmin=0, vmax=255);

# %%
image_applied = fatiamento(image, 3)
imshow(image_applied, cmap='gray', vmin=0, vmax=255);

# %%
image_applied = fatiamento(image, 4)
imshow(image_applied, cmap='gray', vmin=0, vmax=255);

# %%
image_applied = fatiamento(image, 5)
imshow(image_applied, cmap='gray', vmin=0, vmax=255);

# %%
image_applied = fatiamento(image, 6)
imshow(image_applied, cmap='gray', vmin=0, vmax=255);

# %%
image_applied = fatiamento(image, 7)
imshow(image_applied, cmap='gray', vmin=0, vmax=255);

# %%
image_applied = fatiamento(image, 8)
imshow(image_applied, cmap='gray', vmin=0, vmax=255);

# %% [markdown]
# # <p id= 'imagem5'>Imagem 3.20</p>

# %%
def count_intensities(image, num_pixels):
  image_one_array = np.reshape(image, num_pixels)
  intensity_array = np.zeros(256)
  for pixel in image_one_array:
      intensity_array[pixel] += 1

  return intensity_array

# %%
def equalization_histogram(image, intensity, num_pixels):
  image_one_array = np.reshape(image, num_pixels)

  sum_acum = np.cumsum(intensity)

  n = (sum_acum - sum_acum.min()) * 255
  N = sum_acum.max() - sum_acum.min()
  c = n/N
  c = c.astype('uint8')
  
  return c[image_one_array]

# %%
image = imread('entradas/' + imagens[4])
imshow(image, cmap='gray', vmin=0, vmax=255);

# %%
equa = cv.equalizeHist(src=image)
cv.calcHist(equa, [0], None, [256], [0, 256])
plt.hist(equa.ravel(), 256, [0, 256])
plt.title('Histograma Equalizado')
plt.xlabel('Valores dos pixels')
plt.ylabel('Qntd. de pixels')
plt.grid(True)

# %%
imshow(equa, cmap='gray', vmin=0, vmax=255);

# %%
image = imread('entradas/' + imagens[5])
imshow(image, cmap='gray', vmin=0, vmax=255);

# %%
equa = cv.equalizeHist(src=image)
cv.calcHist(equa, [0], None, [256], [0, 256])
plt.hist(equa.ravel(), 256, [0, 256])
plt.title('Histograma Equalizado')
plt.xlabel('Valores dos pixels')
plt.ylabel('Qntd. de pixels')
plt.grid(True)

# %%
imshow(equa, cmap='gray', vmin=0, vmax=255);

# %%
image = imread('entradas/' + imagens[6])
imshow(image, cmap='gray', vmin=0, vmax=255);

# %%
equa = cv.equalizeHist(src=image)
cv.calcHist(equa, [0], None, [256], [0, 256])
plt.hist(equa.ravel(), 256, [0, 256])
plt.title('Histograma Equalizado')
plt.xlabel('Valores dos pixels')
plt.ylabel('Qntd. de pixels')
plt.grid(True)

# %%
imshow(equa, cmap='gray', vmin=0, vmax=255);

# %%
image = imread('entradas/' + imagens[7])
imshow(image, cmap='gray', vmin=0, vmax=255);

# %%
equa = cv.equalizeHist(src=image)
cv.calcHist(equa, [0], None, [256], [0, 256])
plt.hist(equa.ravel(), 256, [0, 256])
plt.title('Histograma Equalizado')
plt.xlabel('Valores dos pixels')
plt.ylabel('Qntd. de pixels')
plt.grid(True)

# %%
imshow(equa, cmap='gray', vmin=0, vmax=255);

# %% [markdown]
# # <p id= 'imagem6'>Imagem 3.24</p>

# %%
image = imread('entradas/' + imagens[8])
imshow(image, cmap='gray', vmin=0, vmax=255);

# %%
equa = cv.equalizeHist(src=image)
cv.calcHist(equa, [0], None, [256], [0, 256])
plt.hist(equa.ravel(), 256, [0, 256])
plt.title('Histograma Equalizado')
plt.xlabel('Valores dos pixels')
plt.ylabel('Qntd. de pixels')
plt.grid(True)

# %%
imshow(equa, cmap='gray', vmin=0, vmax=255);

# %% [markdown]
# # <p id= 'imagem7'>Imagem 3.25</p>

# %% [markdown]
# # <p id= 'imagem8'>Imagem 3.26</p>

# %%
image = imread('entradas/' + imagens[9])
imshow(image, cmap='gray', vmin=0, vmax=255);

# %%
#Equalização Global
equa = cv.equalizeHist(src=image)
imshow(equa, cmap='gray', vmin=0, vmax=255);

# %% [markdown]
# # <p id= 'imagem9'>Imagem 3.27</p>

# %%
image = imread('entradas/' + imagens[10])
imshow(image, cmap='gray', vmin=0, vmax=255);

# %%
#Equalização Global
equa = cv.equalizeHist(src=image)
imshow(equa, cmap='gray', vmin=0, vmax=255);

# %% [markdown]
# # <p id= 'imagem10'>Imagem 3.33</p>

# %%
image = imread('entradas/' + imagens[11])
imshow(image, cmap='gray', vmin=0, vmax=255);

# %%
blur = cv.blur(image,(3,3))
imshow(blur, cmap='gray', vmin=0, vmax=255);

# %%
blur = cv.blur(image,(5,5))
imshow(blur, cmap='gray', vmin=0, vmax=255);

# %%
blur = cv.blur(image,(9,9))
imshow(blur, cmap='gray', vmin=0, vmax=255);

# %%
blur = cv.blur(image,(15,15))
imshow(blur, cmap='gray', vmin=0, vmax=255);

# %%
blur = cv.blur(image,(35,35))
imshow(blur, cmap='gray', vmin=0, vmax=255);

# %% [markdown]
# # <p id= 'imagem11'>Imagem 3.34</p>

# %%
from PIL import ImageFilter
from PIL import Image, ImageEnhance
image = imread('entradas/' + imagens[12])
imshow(image, cmap='gray', vmin=0, vmax=255);
image = Image.fromarray(image)

# %%
img = image.filter(ImageFilter.GaussianBlur(radius=5))
imshow(img, cmap='gray', vmin=0, vmax=255);

# %%
I = np.asarray(img)
image_applied = limiarizacao(I)
imshow(image_applied, cmap='gray', vmin=0, vmax=255);

# %% [markdown]
# # <p id= 'imagem12'>Imagem 3.35</p>

# %%
from PIL import ImageFilter
from PIL import Image, ImageEnhance
image = imread('entradas/' + imagens[13])
imshow(image, cmap='gray', vmin=0, vmax=255);
image2 = Image.fromarray(image)

# %%
img = image2.filter(ImageFilter.GaussianBlur(radius=2))
imshow(img, cmap='gray', vmin=0, vmax=255);

# %%
median = cv.medianBlur(image, 3)
imshow(median, cmap='gray', vmin=0, vmax=255);

# %%
compare = np.concatenate((image, median), axis=1)
imshow(compare, cmap='gray', vmin=0, vmax=255);

# %% [markdown]
# # <p id= 'imagem13'>Imagem 3.38</p>

# %%
image = imread('entradas/' + imagens[14], cv.COLOR_BGR2GRAY)
imshow(image, cmap='gray', vmin=0, vmax=255);

# %%
#A
ddepth = cv.CV_16S
kernel = np.array([[0 , -1 , 0] , [-1 , 4 , -1] ,[0 , -1 , 0]])
sharp_img = cv.filter2D(image , ddepth , kernel = kernel)
imshow(sharp_img, cmap='gray', vmin=0, vmax=255);

# %%
#B
kernel = np.array([[0 , 1 , 0] , [1 , -4 , 1] ,[0 , 1 , 0]])
sharp_img = cv.filter2D(image , ddepth , kernel = kernel)
imshow(sharp_img, cmap='gray', vmin=0, vmax=255);

# %%
#C
kernel = np.array([[1 , 1 , 1] , [1 , -8 , 1] ,[1 , 1 , 1]])
sharp_img = cv.filter2D(image , -1 , kernel = kernel)
imshow(sharp_img, cmap='gray', vmin=0, vmax=255);

# %%
abs_dst = cv.convertScaleAbs(image)
imshow(abs_dst, cmap='gray', vmin=0, vmax=255);

# %%
new_image = cv.Laplacian(image,cv.CV_64F)
imshow(abs_dst, cmap='gray', vmin=0, vmax=255);

# %% [markdown]
# # <p id= 'imagem14'>Imagem 3.40</p>

# %%
image = imread('entradas/' + imagens[15])
imshow(image, cmap='gray', vmin=0, vmax=255);

# %%
blur = cv.GaussianBlur(image,(5,5),sigmaX=3)
imshow(blur, cmap='gray', vmin=0, vmax=255);

# %%
#mascara de nitdez
kernel = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
img2 = cv.filter2D(image, -1, kernel)
imshow(img2, cmap='gray', vmin=0, vmax=255);

# %%
kernel = np.array([[-1 , -1 , -1] , [-1 , 11 , -1] ,[-1 , -1 , -1]])
sharp_img = cv.filter2D(image , -1 , kernel = kernel)
imshow(sharp_img, cmap='gray', vmin=0, vmax=255);

# %% [markdown]
# # <p id= 'imagem15'>Imagem 3.42</p>

# %%
image = imread('entradas/' + imagens[16])
imshow(image, cmap='gray', vmin=0, vmax=255);

# %%
sobelx = cv.Sobel(image,cv.CV_64F,1,0,ksize=5)
imshow(sobelx, cmap='gray', vmin=0, vmax=255)

# %%
sobely = cv.Sobel(image,cv.CV_64F,0,1,ksize=5)
imshow(sobely, cmap='gray', vmin=0, vmax=255)

# %%
grad = cv.addWeighted(sobely, 0.5, sobelx, 0.5, 0)
imshow(grad, cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# # <p id= 'imagem16'>Imagem 3.43</p>

# %%
image = imread('entradas/' + imagens[17])
imshow(image, cmap='gray', vmin=0, vmax=255);
